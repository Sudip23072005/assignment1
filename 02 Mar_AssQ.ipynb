# %% [markdown]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.

# %% [markdown]
# Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python, widely used in data analysis, scientific research, and engineering to generate plots, charts, and figures that aid in visualizing data and deriving insights. It is utilized for its ability to enhance data understanding through graphical representations, extensive customization options, seamless integration with other scientific libraries like NumPy, Pandas, and SciPy, the capability to produce publication-quality plots, and support for interactive plots embedded in applications and web interfaces. The `pyplot` module of Matplotlib can create various plots, including line plots, bar plots, scatter plots, histograms, and pie charts. For instance, a line plot can be created using `plt.plot(x, y)` where `x` and `y` are data arrays; a bar plot with `plt.bar(categories, values)` where `categories` are labels and `values` are their corresponding heights; a scatter plot with `plt.scatter(x, y)` for two sets of data points; a histogram with `plt.hist(data, bins=30)` for distribution of a dataset; and a pie chart with `plt.pie(sizes, labels=labels, autopct='%1.1f%%')` to show proportional data slices.

# %% [markdown]
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.
# import numpy as np
# np.random.seed(3)
# x = 3 + np.random.normal(0, 2, 50)
# y = 3 + np.random.normal(0, 2, len(x))
# Note: Also add title, xlabel, and ylabel to the plot.

# %% [markdown]
# A scatter plot is a type of data visualization that uses dots to represent values for two different numeric variables. The position of each dot on the horizontal and vertical axis indicates values for an individual data point. Scatter plots are useful for displaying the relationship between two variables and can help identify correlations, patterns, clusters, and outliers within the data.

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
plt.scatter(x,y)
plt.title("Random numbers")
plt.xlabel("X coordinate")
plt.ylabel("Y coordinate")
# Out:
# Text(0, 0.5, 'Y coordinate')

# %% [markdown]
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
# Use the following data:
# import numpy as np
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %% [markdown]
# The subplot() function in Matplotlib is used to create multiple plots in a single figure. This function allows you to arrange multiple subplots in a grid layout, making it easier to compare different plots side by side or in a structured manner.

# %%
import matplotlib.pyplot as plt
import numpy as np


x = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])
y2 = np.array([50, 20, 40, 20, 60, 70])
y3 = np.array([10, 20, 30, 40, 50, 60])
y4 = np.array([200, 350, 250, 550, 450, 150])

plt.figure(figsize=(10, 8))

plt.subplot(2, 2, 1)
plt.plot(x, y1, marker='o')
plt.title('Line 1')
plt.xlabel('x')
plt.ylabel('y')


plt.subplot(2, 2, 2)
plt.plot(x, y2, marker='s')
plt.title('Line 2')
plt.xlabel('x')
plt.ylabel('y')

plt.subplot(2, 2, 3)
plt.plot(x, y3, marker='^')
plt.title('Line 3')
plt.xlabel('x')
plt.ylabel('y')


plt.subplot(2, 2, 4)
plt.plot(x, y4, marker='d')
plt.title('Line 4')
plt.xlabel('x')
plt.ylabel('y')


plt.tight_layout()


plt.show()

# %% [markdown]
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
# import numpy as np
# company = np.array(["Apple", "Microsoft", "Google", "AMD"])
# profit = np.array([3000, 8000, 1000, 10000])

# %% [markdown]
# A bar plot, also known as a bar chart, is a graphical representation used to display and compare the quantities of different categories or groups. It consists of rectangular bars with lengths proportional to the values they represent, where the categories are plotted along one axis (usually the x-axis) and the corresponding values along the other axis (usually the y-axis). Bar plots are used to compare discrete categories or groups, making it easy to see which category has the highest or lowest value and to identify patterns or trends within the data. They are commonly used in various fields such as business, finance, and social sciences to present and analyze categorical data in a clear and concise manner.

# %%
import numpy as np
import matplotlib.pyplot as plt
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])
plt.bar(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
# box1 = np.random.normal(100, 10, 200)
# box2 = np.random.normal(90, 20, 200)

# %% [markdown]
# A box plot, also known as a whisker plot, is a standardized way of displaying the distribution of a dataset based on a five-number summary: minimum, first quartile (Q1), median (Q2), third quartile (Q3), and maximum. It consists of a box that represents the interquartile range (IQR), which contains the middle 50% of the data, and "whiskers" that extend to the minimum and maximum values within 1.5 times the IQR from the quartiles. Outliers, which are data points outside this range, are often plotted as individual points.
#
# Why Box Plots are Used:
# Summarize Data: They provide a summary of the data distribution in a compact form, showing central tendency and variability.
# Identify Outliers: Box plots help in identifying outliers in the data, which can be crucial for understanding anomalies.
# Compare Distributions: They are particularly useful for comparing the distribution of data across different groups or categories.

# %%
import matplotlib.pyplot as plt
import numpy as np

box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

plt.boxplot([box1, box2], labels=['Box1', 'Box2'])
plt.title("Box Plot Example")
plt.xlabel("Category")
plt.ylabel("Values")
plt.show()
